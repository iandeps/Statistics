# %% [markdown]
# # LISTS AND TUPLES <hr style = "border:2.5px solid #00ff04ff"></hr>

# %% [markdown]
# <b> Ian Benedict L. Depasucat </b>
# <br> T09-A </br>

# %% [markdown]
# ## Creating a List

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type (numbers)
# Out:
# list

# %%
fruits = ['apple','banana','grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits [-2] = "orange"
fruits
# Out:
# ['apple', 'orange', 'grape']

# %%
mixed_list = [10,"Billiards",20,2.5,True]
mixed_list
# Out:
# [10, 'Billiards', 20, 2.5, True]

# %%
numbers [-3]
# Out:
# 3

# %% [markdown]
# ## ADDING ELEMENTS

# %%
fruits = ['apple','banana','grape']

# %%
fruits.append('orange')
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
fruits.insert(1,'blueberry')
fruits
# Out:
# ['apple', 'blueberry', 'banana', 'grape', 'orange']

# %% [markdown]
# ## Removing Elements

# %%
fruits = ['apple','banana','grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'banana' in fruits
# Out:
# True

# %%
'orange' in fruits
# Out:
# False

# %%
fruits.remove('banana')

# %%
fruits
# Out:
# ['apple', 'grape']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['grape']

# %% [markdown]
# ## sort() and sorted()

# %%
numbers = [3,1,5,4,2]
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
numbers.sort(reverse=True)

# %% [markdown]
# ## SLICING

# %%
numbers = [3,5,1,2,2,3,3,7,8]
numbers
# Out:
# [3, 5, 1, 2, 2, 3, 3, 7, 8]

# %%
len (numbers)
# Out:
# 9

# %%
sub = numbers [1:5]
sub
# Out:
# [5, 1, 2, 2]

# %%
numbers[0:8:2]
# Out:
# [3, 1, 2, 3]

# %% [markdown]
# ## TUPLE

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple[1]= 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 my_tuple[1]= 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple = (1,1,2,3,4,5)
my_tuple
